# %% [markdown]
# # The Kinetic Model of Prothrombinase

# %% [markdown]
# #### Author(s):  Zsolt Csondor
# #### Reference: [BIOMD0000000363](https://www.ebi.ac.uk/biomodels-main/BIOMD0000000363) | [Download](https://cpi-catalog.000webhostapp.com/cpi-files/363.cpi)

# %% [markdown]
# A kinetic model of how thrombin is generated from prothrombin with the intermediates of meizothrombin and prethrombin-2.
#
# Thrombin is an enzyme that plays a role in blood coagulation. It converts soluble fibrinogen into insoluble strands of fibrin, and it also catalises other coagulation-related reactions. Thrombin is generated enzymatically from prothrombin by 2 pathways. There had been conflicting results about the exact reaction rates in the generation of thrombin. The authors of this paper took the conflicting datasets of 2 independent research groups and created a unified kinetic model based on them, then verified the results experimentally. In terms of Cπ code, this is a simple system with 4 reactions, where in each reaction one substance simply changes into another at a certain rate. The plot below shows the reaction rates.

# %%
# %matplotlib notebook

# %%
import sys
sys.path.append('..')
from CPiSimulate import CPi

# %%
cpi_model = CPi.ReadCPiFile('thrombin_activation_minimal')
# Out:
# Select the model: thrombin_activation_minimal
# The processes in this cpi model are:
# Pi

# %% [markdown]
# ## Code

# %%
ode_def = cpi_model.view_processdef('Pi')
# Out:
# The cpi definitions of selected file are:
#
# ---------------------
#
# -- BIOMD0000000363
#
# -- Lee's Minimal Thrombin Activation, 2010
#
# -- cPi model created by Ross Rhodes
#
# ---------------------
#
#
#
# species II() = tau<0.005>.M() + tau<0.0001>.P2();
#
# species IIa() = tau<0.0>.0;
#
# species M() = tau<0.01>.IIa();
#
# species P2() = tau<0.000025>.IIa();
#
#
#
# process Pi = [1.0] II() || [0.0] M() || [0.0] IIa() || [0.0] P2(): {};

# %% [markdown]
# ## Plot

# %%
solution = cpi_model.simulate_process('Pi','odeint', 0, 900, 9000)
solution.show_plot()
# Out:
# Time Start: 0.0, Time End: 900.0, Number of Times: 9000.
# <img src="data:image/png;base64,..." width="1200">
